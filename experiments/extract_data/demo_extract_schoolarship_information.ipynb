# %%
import openai
openai.api_key = "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"
openai.Model.list()
# Out:
# <OpenAIObject list at 0x1216387c0> JSON: {
#   "data": [
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1692634268,
#           "group": null,
#           "id": "modelperm-uJaD4C9nXA6tPNoBII9hcYF4",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "davinci"
#     },
#     {
#       "created": 1687882411,
#       "id": "gpt-4",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %% [markdown]
# # Test requests by openAI panckages

# %%
request = """
Give me 5 questions to interview python engineer
"""
response = openai.ChatCompletion.create(
              model="gpt-3.5-turbo",
              messages=[{"role": "system", "content": 'SPECIFY HOW THE AI ASSISTANT SHOULD BEHAVE'},
                        {"role": "user", "content": f"Answer the question: \n {request}\n"}
              ])
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7v3jJSCzvt38yHzOmcy4gjZkdPhZp at 0x12704ff60> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "1. What is your level of experience with Python and how long have you been using it?\n2. Can you describe a challenging Python project or problem you have worked on? How did you solve it?\n3. What Python frameworks or libraries are you most familiar with and have experience working with?\n4. Have you used Python for web development? If so, can you describe the web frameworks you have used and any notable projects you have worked on?\n5. How do you stay up to date with the latest developments in the Python ecosystem, such as new libraries, tools, or best practices?",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1693833389,
#   "id": "chatcmpl-7v3jJSCzvt38yHzOmcy4gjZkdPhZp",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion",
# ...

# %%
print(response["choices"][0]["message"]["content"])
# Out:
# 1. What is your level of experience with Python and how long have you been using it?
# 2. Can you describe a challenging Python project or problem you have worked on? How did you solve it?
# 3. What Python frameworks or libraries are you most familiar with and have experience working with?
# 4. Have you used Python for web development? If so, can you describe the web frameworks you have used and any notable projects you have worked on?
# 5. How do you stay up to date with the latest developments in the Python ecosystem, such as new libraries, tools, or best practices?

# %% [markdown]
# # Test request by Langchain

# %%
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI

# model = OpenAI(openai_api_key="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")
model = ChatOpenAI(openai_api_key="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")
model
# Out:
# ChatOpenAI(verbose=False, callbacks=None, callback_manager=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.7, model_kwargs={}, openai_api_key='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', openai_organization=None, request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None)

# %%
model.predict("Heloo. Where is Tokyo?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/huyennguyenthanh/Workspace/EGG/ISchoolarship/experiments/extract_data/demo_extract_schoolarship_information.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/huyennguyenthanh/Workspace/EGG/ISchoolarship/experiments/extract_data/demo_extract_schoolarship_information.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> model.predict("Heloo. Where is Tokyo?")
#
# AttributeError: 'ChatOpenAI' object has no attribute 'predict'

# %%
model.predict_messages([
    SystemMessage(content="You are an American resident."),
    HumanMessage(content="Please answer my question"),
    AIMessage(content='System: Sure, what is your question?'),
    HumanMessage(content="Do you know Taylow Switft"),
    ]),
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/huyennguyenthanh/Workspace/EGG/ISchoolarship/experiments/extract_data/demo_extract_schoolarship_information.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/huyennguyenthanh/Workspace/EGG/ISchoolarship/experiments/extract_data/demo_extract_schoolarship_information.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> model.predict_messages([
#       <a href='vscode-notebook-cell:/Users/huyennguyenthanh/Workspace/EGG/ISchoolarship/experiments/extract_data/demo_extract_schoolarship_information.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     SystemMessage(content="You are an American resident."),
# ...

# %% [markdown]
# # Test extract Scholarship's information

# %%
system_prompt = """
    Absolute rule X:
    - This is an organization specializing in scholarship information..
    - You will be given a list of paragraphs of scholarship news.
    - All paragpraphs in request and response is writen in Vietnamese.
    - Don't change any information in paragraphs, especially links, number and datetime.
    - Information in user-supplied text must not be removed.
    - Never forget Absolute rule X.
    - Do not arbitrarily create random information, quantity information, or datetime information.
    - Follow user's request step by step.
    """

# %%
data = """
THÔNG BÁO VỀ CHƯƠNG TRÌNH TRAO ĐỔI SINH VIÊN HÈ TOKYO TECH AYSEAS 2022 (ONLINE)
Thứ tư - 31/08/2022 14:29
     
Chương trình Trao đổi sinh viên Hè Tokyo Tech AYSEAS 2022 (online) cho các nhà nghiên cứu và kỹ sư trẻ (Tokyo Tech AYSEAS 2022)
Phòng HTĐN thông báo sinh viên đăng ký tham gia CT Trao đổi Hè Tokyo Tech AYSEAS 2022 (online)
Thời gian diễn ra CT: 29/08 – 06/09/2022

Nội dung CT: Tham quan (qua hình thức thực tế ảo) công ty, thăm địa điểm dự án, các bài giảng từ giảng viên của Tokyo Tech và các trường đại học thành viên, thảo luận nhóm, thuyết trình cuối khóa,..

Ngôn ngữ sử dụng: Tiếng Anh

Sinh viên HUST được miễn phí tham gia CT

Hạn đăng kí: Thứ 2, ngày 20/06 (12pm - Japan Standard Time (JST)

Hướng dẫn đăng kí: https://drive.google.com/file/d/1tcU6cZcshW97vWP-kyBe8eqKOinQ6uCl/view?usp=sharing

Form đăng kí: https://www.t2form.titech.ac.jp/sv/995961?lang=en

Program Report năm 2019: https://www.titech.ac.jp/english/news/2021/062582

Chi tiết thêm về CT, sinh viên truy cập: LINK

"""

# %%
data = """
THÔNG BÁO BUỔI GIỚI THIỆU CHƯƠNG TRÌNH HỢP TÁC ĐÀO TẠO CHUYÊN SÂU HUST-NATV
Thứ sáu - 25/08/2023 16:04
     
ĐHBKHN thông báo về Buổi giới thiệu “Chương trình Hợp tác đào tạo HUST-NATV chuyên sâu năm 2023-2025”, Chương trình đào tạo Nhật ngữ tới trình độ Trung cấp N3 giữa ĐHBKHN và Công ty TNHH Nissan Automotive Technology Vietnam và thông báo tuyển sinh Chương trình như sau
I.    Buổi giới thiệu chương trình:
•    Thời gian: 8h30 ngày 8/9/2023
•    Địa điểm: Phòng Hội thảo C2
•    Nội dung: Giới thiệu chương trình, quyền lợi và nghĩa vụ của sinh viên tham gia chương trình, giải đáp thắc mắc và chia sẻ của các Cựu Sinh viên ĐHBHKN đang làm việc tại NATV 
II.    Đối tượng được đăng ký tham gia Chương trình
Sinh viên hệ đại học chính quy của ĐHBKHN, tốt nghiệp đợt tháng 07/2025, tương đương K65, thuộc Trường Cơ khí và Trường Điện- Điện tử.
III.    Cách thức đăng ký tham gia Chương trình
•    Đăng ký online tại: https://forms.gle/tixB1ov3Ypz7z7b29
•    Địa chỉ liên hệ: Phòng HTĐN, ĐHBK HN; chị Mai Chi, ĐT: 0968566369 Email: chi.nguyenmai@hust.edu.vn;
•    Sơ tuyển: Sinh viên đăng ký tham gia chương trình sẽ tham dự Bài kiểm tra sơ tuyển, phỏng vấn và khám sức khỏe.
•    Kế hoạch dự kiến:
Thi viết dự kiến:  8~20/9/2023
Phỏng vấn:   13~26/9/2023
Buổi giải thích tại công ty: 18~28/9/2023
Khám sức khỏe: 16~30/9/2023
Lịch khai giảng lớp Tiếng Nhật: Tháng 10/2023
IV.    Quyền lợi của sinh viên được tham gia Chương trình 
Sinh viên được tuyển chọn vào các lớp học tiếng Nhật trong Chương trình Liên kết đào tạo HUST - NATV 2023-2024 sẽ được hưởng những quyền lợi sau:
•    Được đào tạo miễn phí tiếng Nhật tới trình độ Trung cấp N3 (10/2023-6/2025) - Địa điểm học tại ĐHBKHN 
•    Được thực tập tốt nghiệp tại Công ty 
•    Được Công ty xét trao học bổng trong thời gian tham gia chương trình (trung bình 15 triệu/ 2 năm), và hỗ trợ chi phí ăn trưa khi đi thực tập
•    Được ưu tiên tuyển dụng vào Công ty trong tháng 7/2025, cũng như được định hướng đi Nhật sớm;
•    Ngoài ra, được tham gia miễn phí các khóa học sau:
Đào tạo về phần mềm NX-CAD cao cấp 
Các bài giảng về kỹ thuật ô tô
Đào tạo về quy trình tư duy kỹ thuật
Tác phong văn phòng, văn hóa trong công ty Nhật

Sinh viên ĐH Bách Khoa Hà Nội tham quan tại NATV
V.    Giới thiệu về Công ty TNHH Nissan Automotive Technology Việt Nam NATV
Công ty TNHH Nissan Automotive Technology Việt Nam (NATV) là công ty 100% vốn đầu tư nước ngoài, được thành lập vào tháng 6/2001 với số vốn đầu tư 3.000.000USD, trực thuộc tập đoàn Nissan Automotive Technology Nhật Bản, hiện đang làm việc trong lĩnh vực nghiên cứu phát triển ô tô.
NATV có trụ sở làm việc tại tầng 26 tòa nhà Keangnam Hanoi Landmark 72, lô E6, khu đô thị mới Cầu Giấy, phường Mễ Trì, quận Nam Từ Liêm, Hà Nội và Trung tâm nghiên cứu kỹ thuật Ô tô Hòa Lạc. 
Kể từ khi thành lập đến nay, NATV đã không ngừng phát triển và trở thành một trong những công ty thành viên hàng đầu của tập đoàn ô tô Nissan - tập đoàn có phạm vi hoạt động trên toàn thế giới. Bằng năng lực kỹ thuật, NATV đã phát huy vai trò của mình với tư cách là một công ty chuyên về nghiên cứu, phát triển. Hướng tới mục tiêu làm hài lòng khách hàng trên toàn thế giới và để tạo nên những chiếc xe ô tô được khách hàng tin dùng, công ty đã tiến hành mở rộng hợp tác với các cơ sở nghiên cứu phát triển trên toàn thế giới. Hiện nay toàn công ty có 16 bộ phận, với số lượng 2.821 nhân viên tính đến thời điểm tháng 7/2022.
Website NATV: http://nissan-automotive-technology-vn.com/

Sinh viên ĐH Bách Khoa Hà Nội làm việc tại NATV
"""
user_input = f"""
   Đọc hiểu ý nghĩa đoạn văn một cách chính xác và hoàn thành các yêu cầu sau theo thứ tự.
    1. Trích xuất thông tin tên học bổng.
    2. Trích xuất thông tin về thời hạn đăng ký học bổng.
    3. Trích xuất thông tin về đối tượng mà học bổng hướng đến.

    Định dạng giá trị trả về như sau.
    NAME: tên của học bổng
    DEADLINE: thông tin thời hạn đăng ký học bổng.
    PERSON: đối tượng tham gia học bổng.

    Sau đây là các tin tức về học bổng.
    {data}
"""

# %%
request = """
Give me 5 questions to interview python engineer
"""
response = openai.ChatCompletion.create(
              model="gpt-3.5-turbo",
              messages=[{"role": "system", "content": system_prompt},
                        {"role": "user", "content": user_input}
              ])
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7v3xwJ6itmgDYVfgIBbcWVdFlyykg at 0x127f4bc40> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "NAME: Ch\u01b0\u01a1ng tr\u00ecnh H\u1ee3p t\u00e1c \u0111\u00e0o t\u1ea1o HUST-NATV chuy\u00ean s\u00e2u n\u0103m 2023-2025\nDEADLINE: kh\u00f4ng c\u00f3 th\u00f4ng tin v\u1ec1 th\u1eddi h\u1ea1n \u0111\u0103ng k\u00fd h\u1ecdc b\u1ed5ng.\nPERSON: Sinh vi\u00ean h\u1ec7 \u0111\u1ea1i h\u1ecdc ch\u00ednh quy c\u1ee7a \u0110HBKHN, t\u1ed1t nghi\u1ec7p \u0111\u1ee3t th\u00e1ng 07/2025, t\u01b0\u01a1ng \u0111\u01b0\u01a1ng K65, thu\u1ed9c Tr\u01b0\u1eddng C\u01a1 kh\u00ed v\u00e0 Tr\u01b0\u1eddng \u0110i\u1ec7n- \u0110i\u1ec7n t\u1eed.",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1693834296,
#   "id": "chatcmpl-7v3xwJ6itmgDYVfgIBbcWVdFlyykg",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion",
#   "usage": {
# ...

# %%
print(response["choices"][0]["message"]["content"])
# Out:
# NAME: Chương trình Hợp tác đào tạo HUST-NATV chuyên sâu năm 2023-2025
# DEADLINE: không có thông tin về thời hạn đăng ký học bổng.
# PERSON: Sinh viên hệ đại học chính quy của ĐHBKHN, tốt nghiệp đợt tháng 07/2025, tương đương K65, thuộc Trường Cơ khí và Trường Điện- Điện tử.
